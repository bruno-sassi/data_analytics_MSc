# %%
pip install tabpy
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/533.6 kB ? eta -:--:--
#    ---------------------------------------- 533.6/533.6 kB 8.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    --------------------------------------- 624.3/624.3 kB 11.7 MB/s eta 0:00:00
# ...
#   Created wheel for tabpy: filename=tabpy-2.13.0-py2.py3-none-any.whl size=122652 sha256=0792d9d1fa24c534be9557b01db29ac5ddeee14a7de39fe8d2b42a758067ea86
#   Stored in directory: c:\users\bruno\appdata\local\pip\cache\wheels\a9\6d\8c\1e52e6bdbfdcf992c9e64d54f059cf99c1b7cf759c3f7b43ad
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13775 sha256=d3a9b7faf20763d96c43ae2befec35931e88fbd16040cc57d47e97dd616d03a2
# ...

# %%
import tabpy

# %%
import pandas as pd

df = pd.read_csv('carbon-emissions-borough.csv')
df.T
# Out:
#                            0    1               2                     3   \
# Unnamed: 0               Code  NaN       E09000001             E09000002
# Unnamed: 1               Name  NaN  City of London  Barking and Dagenham
# Industry and Commercial  2005  NaN         1,545.7                 345.8
# Unnamed: 3               2006  NaN         1,679.7                 348.1
# Unnamed: 4               2007  NaN         1,580.4                 346.8
# ...                       ...  ...             ...                   ...
# Unnamed: 64               NaN  NaN             NaN                   NaN
# Unnamed: 65               NaN  NaN             NaN                   NaN
# Unnamed: 66               NaN  NaN             NaN                   NaN
# Unnamed: 67               NaN  NaN             NaN                   NaN
# Unnamed: 68               NaN  NaN             NaN                   NaN
#
#                                 4          5          6          7   \
# ...

# %%
df.T

# drop rows and columns with all NaN values
df_cleaned = df.dropna(axis=0, how='all').dropna(axis=1, how='all')
df_ready = df_cleaned.T

# transform index into a column
df_ready.reset_index(inplace=True)
df_ready

# export to CSV
df_ready.to_csv('carbon-emissions-borough_cleaned.csv', index=False)
