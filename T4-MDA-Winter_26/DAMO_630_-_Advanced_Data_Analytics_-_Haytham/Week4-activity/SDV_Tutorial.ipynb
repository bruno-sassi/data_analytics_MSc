# %%
import pandas as pd
from sdv.single_table import CTGANSynthesizer, GaussianCopulaSynthesizer
from sdv.metadata import Metadata

# %%
data = pd.read_csv('adult_census.csv')
real_data = data.sample(n=2000, random_state=42).reset_index(drop=True)
real_data.head()
# Out:
#    age         workclass  fnlwgt     education  education_num  \
# 0   27           Private  160178  Some-college             10
# 1   45         State-gov   50567       HS-grad              9
# 2   29           Private  185908     Bachelors             13
# 3   30           Private  190040     Bachelors             13
# 4   29  Self-emp-not-inc  189346  Some-college             10
#
#        marital_status         occupation   relationship   race     sex  \
# 0            Divorced       Adm-clerical  Not-in-family  White  Female
# 1  Married-civ-spouse    Exec-managerial           Wife  White  Female
# 2  Married-civ-spouse    Exec-managerial        Husband  Black    Male
# 3       Never-married  Machine-op-inspct  Not-in-family  White  Female
# 4            Divorced       Craft-repair  Not-in-family  White    Male
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0             0             0              38  United-States  <=50K
# 1             0             0              40  United-States  <=50K
# 2             0             0              55  United-States   >50K
# 3             0             0              40  United-States  <=50K
# 4          2202             0              50  United-States  <=50K

# %%
metadata = Metadata.detect_from_dataframe(real_data)

# %%
metadata.save_to_json('metadata.json')

# %%
synthesizer = GaussianCopulaSynthesizer(metadata)
synthesizer.fit(real_data)
synthetic_data = synthesizer.sample(2000)
synthetic_data.head()
# Out:
#    age workclass  fnlwgt  education  education_num      marital_status  \
# 0   50   Private  220539        9th              2  Married-civ-spouse
# 1   54   Private   90861    HS-grad              2  Married-civ-spouse
# 2   20   Private  223117    HS-grad              2       Never-married
# 3   26   Private  153369  Bachelors              2  Married-civ-spouse
# 4   19   Private  224088       10th              2  Married-civ-spouse
#
#         occupation   relationship   race     sex  capital_gain  capital_loss  \
# 0  Exec-managerial  Not-in-family  Black    Male             2          2221
# 1     Adm-clerical      Own-child  White    Male             0          1924
# 2  Exec-managerial      Unmarried  White  Female             0          2009
# 3     Craft-repair  Not-in-family  White    Male             0          1967
# 4  Farming-fishing      Own-child  White    Male             9          1800
#
#    hours_per_week native_country income
# 0              42  United-States  <=50K
# 1              42           Iran  <=50K
# 2              42  United-States   >50K
# 3              42  United-States  <=50K
# 4              42  United-States  <=50K

# %%
from sdv.evaluation.single_table import run_diagnostic
diagnostic = run_diagnostic(
    real_data=real_data,
    synthetic_data=synthetic_data,
    metadata=metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |████████████| 15/15 [00:00<00:00, 1065.03it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████████| 1/1 [00:00<00:00, 338.30it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%

# %%
from sdv.evaluation.single_table import evaluate_quality

quality_report = evaluate_quality(
    real_data,
    synthetic_data,
    metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |█████████████| 15/15 [00:00<00:00, 617.34it/s]|
# Column Shapes Score: 77.84%
#
# (2/2) Evaluating Column Pair Trends: |██████| 105/105 [00:00<00:00, 788.21it/s]|
# Column Pair Trends Score: 66.66%
#
# Overall Score (Average): 72.25%

# %%
from sdv.evaluation.single_table import get_column_plot

fig = get_column_plot(
    real_data=real_data,
    synthetic_data=synthetic_data,
    column_name='occupation',
    metadata=metadata
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_27.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
