# %% [markdown]
# # Hugging Face Sentiment Analysis on NLTK Twitter Samples
#
# This notebook walks through the full pipeline to evaluate a Hugging Face sentiment analysis model on a subset of the NLTK `twitter_samples` dataset.
#
# **Steps**
# 1. Install required libraries
# 2. Import libraries
# 3. Download dataset
# 4. Load tweets & labels
# 5. Load Hugging Face sentiment pipeline
# 6. Predict sentiment using the model
# 7. Convert predictions to binary labels
# 8. Print performance metrics

# %% [markdown]
# ## Step 1: Install Required Libraries
# This installs NLTK (for the dataset), Transformers (for the pretrained sentiment model), and scikit-learn (for evaluation metrics).

# %%
# !pip install -q nltk transformers scikit-learn torch

# %%
dbutils.library.restartPython()

# %% [markdown]
# ## Step 2: Import Libraries

# %%
import nltk
from nltk.corpus import twitter_samples
from transformers import pipeline
from sklearn.metrics import classification_report

# %% [markdown]
# ## Step 3: Download the `twitter_samples` Dataset

# %%
nltk.download('twitter_samples')

# %% [markdown]
# ## Step 4: Load Tweets & Labels
# We load 160 positive and 220 negative tweets. Labels: **1** for positive, **0** for negative.

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')[:160]
negative_tweets = twitter_samples.strings('negative_tweets.json')[:220]

texts = positive_tweets + negative_tweets
true_labels = [1] * len(positive_tweets) + [0] * len(negative_tweets)

print(f'Loaded {len(texts)} tweets: {len(positive_tweets)} positive, {len(negative_tweets)} negative')
print('Sample tweet:', texts[0])

# %% [markdown]
# ## Step 5: Load Hugging Face Sentiment Pipeline
# We use `distilbert-base-uncased-finetuned-sst-2-english`, a lightweight DistilBERT model fine-tuned on SST-2 for binary sentiment classification.

# %%
# Your Code Here

# %% [markdown]
# ## Step 6: Predict Sentiment Using the Model
# The pipeline predicts a label (POSITIVE/NEGATIVE) and a confidence score for each tweet.

# %%
# Your Code Here

# %% [markdown]
# ## Step 7: Convert Predictions to Binary Labels
# Map POSITIVE to 1 and NEGATIVE to 0.

# %%
# Your Code Here

# %% [markdown]
# ## Step 8: Print Performance Metrics
# We compare the true labels to the predicted labels and print precision, recall, F1-score, and support.

# %%
# Your Code Here

# %% [markdown]
# ## Step 9: Try alternative models and comapre with the `distilbert-base-uncased-finetuned-sst-2-english`
